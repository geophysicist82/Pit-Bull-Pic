# %% [markdown]
# ## Data scraping and download

# %%
import time
import petpy
import os
import json
import pandas as pd
import urllib.request
import urllib.error
from multiprocessing import Pool
from multiprocessing.dummy import Pool as ThreadPool

# %%
#key = os.getenv('PETFINDER_KEY')
pf = petpy.Petfinder('key', 'secret')

# %% [markdown]
# For my image search I decided to start in Texas. I used Brady, Tx as the location since it is the center of Texas and set the distance to 500 to get the whole state.
# I am scraping 10k dog images.

# %%
breeds = pf.animals(location=76825, animal_type='dog', distance=500, pages=100, results_per_page=100, return_df=True)

# %%
breeds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9813 entries, 0 to 9999
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   url                           9813 non-null   object
#  1   type                          9813 non-null   object
#  2   species                       9813 non-null   object
#  3   age                           9813 non-null   object
#  4   gender                        9813 non-null   object
#  5   size                          9813 non-null   object
#  6   coat                          2855 non-null   object
#  7   name                          9813 non-null   object
#  8   description                   7318 non-null   object
#  9   photos                        9813 non-null   object
#  10  videos                        9813 non-null   object
#  11  breeds.primary                9813 non-null   object
#  12  breeds.secondary              3734 non-null   object
#  13  breeds.mixed                  9813 non-null   bool
#  14  breeds.unknown                9813 non-null   bool
#  15  colors.primary                4515 non-null   object
#  16  colors.secondary              2173 non-null   object
#  17  colors.tertiary               173 non-null    object
#  18  primary_photo_cropped.small   9813 non-null   object
#  19  primary_photo_cropped.medium  9813 non-null   object
#  20  primary_photo_cropped.large   9813 non-null   object
#  21  primary_photo_cropped.full    9813 non-null   object
#  22  animal_type                   9813 non-null   object
#  23  primary_photo_cropped         0 non-null      float64
# dtypes: bool(2), float64(1), object(21)
# memory usage: 1.7+ MB

# %%
breeds.head()
# Out:
#                                                  url type species     age  \
# 0  https://www.petfinder.com/dog/bud-49113000/tx/...  Dog     Dog    Baby
# 1  https://www.petfinder.com/dog/daisy-49113009/t...  Dog     Dog   Young
# 2  https://www.petfinder.com/dog/phillip-20-09-09...  Dog     Dog  Senior
# 3  https://www.petfinder.com/dog/sophie-reutter-2...  Dog     Dog   Young
# 4  https://www.petfinder.com/dog/ramona-49112958/...  Dog     Dog    Baby
#
#    gender    size   coat                      name  \
# 0    Male  Medium  Short                       BUD
# 1  Female  Medium   None                     Daisy
# 2    Male   Large   None         Phillip 20-09-095
# 3  Female  Medium   None  Sophie Reutter 20-09-094
# 4  Female   Small  Short                    Ramona
#
#                                          description  \
# 0  Hi! I’m Bud, a 6-month-old Cur/Collie mix. I’m...
# 1                                               None
# 2                                               None
# 3                                               None
# 4  These adorably tiny chi mixes will make your l...
#
#                                               photos  ... breeds.unknown  \
# 0  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...  ...          False
# 1                                                 []  ...          False
# 2                                                 []  ...          False
# 3                                                 []  ...          False
# 4  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...  ...          False
#
#                 colors.primary             colors.secondary  colors.tertiary  \
# 0                        Black                White / Cream             None
# 1  Yellow / Tan / Blond / Fawn                White / Cream             None
# 2  Yellow / Tan / Blond / Fawn                         None             None
# 3  Yellow / Tan / Blond / Fawn                         None             None
# 4                        Black  Yellow / Tan / Blond / Fawn             None
#
#                          primary_photo_cropped.small  \
# 0  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                         primary_photo_cropped.medium  \
# 0  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                          primary_photo_cropped.large  \
# 0  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                           primary_photo_cropped.full animal_type  \
# 0  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...         dog
# 1                                                NaN         dog
# 2                                                NaN         dog
# 3                                                NaN         dog
# 4  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...         dog
#
#   primary_photo_cropped
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# Here I drop many of the columns I don't need to clean up my dataframe.

# %%
breeds.drop(columns=['attributes.spayed_neutered','attributes.house_trained','attributes.declawed',
                    'attributes.special_needs','attributes.shots_current','environment.children', 
                     'environment.dogs', 'environment.cats','contact.email', 'contact.phone', 
                     'contact.address.address1','contact.address.address2', 'contact.address.city',
                     'contact.address.state', 'contact.address.postcode',
                     'contact.address.country','organization_id','status', 'tags','status_changed_at', 
                     'published_at', 'distance', 'animal_id', 'organization_animal_id'], inplace=True)

# %% [markdown]
# I am again going to export my dataframe to a CSV so I will not have to re-scrape any data.

# %%
#breeds.to_csv('./data/10k_mostlyraw_9-16-20.csv')

# %%
#breeds=pd.read_csv('./data/10k_mostlyraw_9-16-20.csv')

# %%
breeds.columns
# Out:
# Index(['id', 'url', 'type', 'species', 'age', 'gender', 'size', 'coat', 'name',
#        'description', 'photos', 'videos', 'breeds.primary', 'breeds.secondary',
#        'breeds.mixed', 'breeds.unknown', 'colors.primary', 'colors.secondary',
#        'colors.tertiary', 'primary_photo_cropped.small',
#        'primary_photo_cropped.medium', 'primary_photo_cropped.large',
#        'primary_photo_cropped.full', 'animal_type', 'primary_photo_cropped'],
#       dtype='object')

# %%
pf.animal_types('dog')
# Out:
# {'type': {'name': 'Dog',
#   'coats': ['Hairless', 'Short', 'Medium', 'Long', 'Wire', 'Curly'],
#   'colors': ['Apricot / Beige',
#    'Bicolor',
#    'Black',
#    'Brindle',
#    'Brown / Chocolate',
#    'Golden',
#    'Gray / Blue / Silver',
#    'Harlequin',
#    'Merle (Blue)',
#    'Merle (Red)',
#    'Red / Chestnut / Orange',
#    'Sable',
#    'Tricolor (Brown, Black, & White)',
#    'White / Cream',
#    'Yellow / Tan / Blond / Fawn'],
#   'genders': ['Male', 'Female'],
#   '_links': {'self': {'href': '/v2/types/dog'},
#    'breeds': {'href': '/v2/types/dog/breeds'}}}}

# %% [markdown]
# I am dropping all rows that have null values for all the photo columns.

# %%
breeds = breeds[breeds['primary_photo_cropped.small'].notna()]
breeds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9813 entries, 0 to 9999
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            9813 non-null   int64
#  1   url                           9813 non-null   object
#  2   type                          9813 non-null   object
#  3   species                       9813 non-null   object
#  4   age                           9813 non-null   object
#  5   gender                        9813 non-null   object
#  6   size                          9813 non-null   object
#  7   coat                          2855 non-null   object
#  8   name                          9813 non-null   object
#  9   description                   7318 non-null   object
#  10  photos                        9813 non-null   object
#  11  videos                        9813 non-null   object
#  12  breeds.primary                9813 non-null   object
#  13  breeds.secondary              3734 non-null   object
#  14  breeds.mixed                  9813 non-null   bool
#  15  breeds.unknown                9813 non-null   bool
#  16  colors.primary                4515 non-null   object
#  17  colors.secondary              2173 non-null   object
#  18  colors.tertiary               173 non-null    object
#  19  primary_photo_cropped.small   9813 non-null   object
#  20  primary_photo_cropped.medium  9813 non-null   object
#  21  primary_photo_cropped.large   9813 non-null   object
#  22  primary_photo_cropped.full    9813 non-null   object
#  23  animal_type                   9813 non-null   object
#  24  primary_photo_cropped         0 non-null      float64
# dtypes: bool(2), float64(1), int64(1), object(21)
# memory usage: 1.8+ MB

# %% [markdown]
# I am saving another version of the dataframe to csv.

# %%
#breeds.to_csv('./data/10k_mostlyraw_9-16-20CLEANED.csv')

# %%
#breeds=pd.read_csv('./data/10k_mostlyraw_9-16-20CLEANED.csv')

# %% [markdown]
# Now I remove all columns except ones that contain id, breed and photo.

# %%
photos = breeds[breeds.columns[breeds.columns.str.contains('id|breed|photo')]]

# %%
photos
# Out:
#             id                                             photos videos  \
# 0     49113000  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     []
# 4     49112958  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     []
# 6     49112972  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     []
# 7     49112968  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     []
# 8     49112969  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     []
# ...        ...                                                ...    ...
# 9995  45801263  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     []
# 9996  45795879  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     []
# 9997  45795880  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     []
# 9998  45795882  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     []
# 9999  45795884  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     []
#
#            breeds.primary breeds.secondary  breeds.mixed  breeds.unknown  \
# 0         Black Mouth Cur           Collie          True           False
# 4               Chihuahua              NaN         False           False
# 6                Shepherd              NaN          True           False
# 7     German Shepherd Dog              NaN         False           False
# 8             Mixed Breed              NaN         False           False
# ...                   ...              ...           ...             ...
# 9995   Labrador Retriever      Mixed Breed          True           False
# 9996             Shepherd              NaN          True           False
# 9997   Labrador Retriever       Cattle Dog          True           False
# 9998             Shepherd              NaN          True           False
# 9999           Cattle Dog              NaN         False           False
#
#                             primary_photo_cropped.small  \
# 0     https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 4     https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 6     https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 7     https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 8     https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# ...                                                 ...
# 9995  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 9996  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 9997  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 9998  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 9999  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                            primary_photo_cropped.medium  \
# 0     https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 4     https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 6     https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 7     https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 8     https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# ...                                                 ...
# 9995  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 9996  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 9997  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 9998  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 9999  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                             primary_photo_cropped.large  \
# 0     https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 4     https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 6     https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 7     https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 8     https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# ...                                                 ...
# 9995  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 9996  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 9997  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 9998  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 9999  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                              primary_photo_cropped.full  \
# 0     https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 4     https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 6     https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 7     https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 8     https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# ...                                                 ...
# 9995  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 9996  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 9997  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 9998  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 9999  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#       primary_photo_cropped  image_width
# 0                       NaN          600
# 4                       NaN          600
# 6                       NaN          600
# 7                       NaN          600
# 8                       NaN          600
# ...                     ...          ...
# 9995                    NaN          600
# 9996                    NaN          600
# 9997                    NaN          600
# 9998                    NaN          600
# 9999                    NaN          600
#
# [9813 rows x 13 columns]

# %% [markdown]
# I am getting the size of the largest photos because those are the ones I will download.

# %%
photos['image_width'] = photos['primary_photo_cropped.large'].str.split('width=', 1).str[1].str.split('&', 0).str[0].astype(int)
# Out:
# /Users/jennyjames/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# I create a column called image_width to display the size of the large photos.

# %%
photos['image_width'].unique()
# Out:
# array([600])

# %% [markdown]
# I set the index to be the dog id column.

# %%
photos.set_index('id')
# Out:
#                                                      photos videos  \
# id
# 49113000  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     []
# 49112958  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     []
# 49112972  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     []
# 49112968  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     []
# 49112969  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     []
# ...                                                     ...    ...
# 45801263  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     []
# 45795879  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     []
# 45795880  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     []
# 45795882  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     []
# 45795884  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     []
#
#                breeds.primary breeds.secondary  breeds.mixed  breeds.unknown  \
# id
# 49113000      Black Mouth Cur           Collie          True           False
# 49112958            Chihuahua              NaN         False           False
# 49112972             Shepherd              NaN          True           False
# 49112968  German Shepherd Dog              NaN         False           False
# 49112969          Mixed Breed              NaN         False           False
# ...                       ...              ...           ...             ...
# 45801263   Labrador Retriever      Mixed Breed          True           False
# 45795879             Shepherd              NaN          True           False
# 45795880   Labrador Retriever       Cattle Dog          True           False
# 45795882             Shepherd              NaN          True           False
# 45795884           Cattle Dog              NaN         False           False
#
#                                 primary_photo_cropped.small  \
# id
# 49113000  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49112958  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49112972  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49112968  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49112969  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# ...                                                     ...
# 45801263  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 45795879  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 45795880  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 45795882  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 45795884  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                                primary_photo_cropped.medium  \
# id
# 49113000  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49112958  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49112972  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49112968  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49112969  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# ...                                                     ...
# 45801263  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 45795879  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 45795880  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 45795882  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 45795884  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                                 primary_photo_cropped.large  \
# id
# 49113000  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49112958  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49112972  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49112968  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49112969  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# ...                                                     ...
# 45801263  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 45795879  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 45795880  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 45795882  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 45795884  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                                  primary_photo_cropped.full  \
# id
# 49113000  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49112958  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49112972  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49112968  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49112969  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# ...                                                     ...
# 45801263  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 45795879  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 45795880  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 45795882  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 45795884  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#           primary_photo_cropped  image_width
# id
# 49113000                    NaN          600
# 49112958                    NaN          600
# 49112972                    NaN          600
# 49112968                    NaN          600
# 49112969                    NaN          600
# ...                         ...          ...
# 45801263                    NaN          600
# 45795879                    NaN          600
# 45795880                    NaN          600
# 45795882                    NaN          600
# 45795884                    NaN          600
#
# [9813 rows x 12 columns]

# %% [markdown]
# I am only keeping the images that have a width of 600.

# %%
largephotos = photos.groupby('id').apply(lambda x: x[x['image_width'] == 600])

# %%
largephotos.head()
# Out:
#          id                                             photos videos  \
# 0  45795879  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     []
# 1  45795880  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     []
# 2  45795882  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     []
# 3  45795884  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     []
# 4  45801263  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     []
#
#        breeds.primary breeds.secondary  breeds.mixed  breeds.unknown  \
# 0            Shepherd              NaN          True           False
# 1  Labrador Retriever       Cattle Dog          True           False
# 2            Shepherd              NaN          True           False
# 3          Cattle Dog              NaN         False           False
# 4  Labrador Retriever      Mixed Breed          True           False
#
#                          primary_photo_cropped.small  \
# 0  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 1  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 2  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 4  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                         primary_photo_cropped.medium  \
# 0  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 1  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 2  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 4  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                          primary_photo_cropped.large  \
# 0  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 1  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 2  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 4  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                           primary_photo_cropped.full  primary_photo_cropped  \
# 0  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...                    NaN
# 1  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...                    NaN
# 2  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...                    NaN
# 3  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...                    NaN
# 4  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...                    NaN
#
#    image_width
# 0          600
# 1          600
# 2          600
# 3          600
# 4          600

# %% [markdown]
# Now my dataset has a few extra columns so I delete those and reset the index to be the dog id.

# %%
del largephotos['id']
largephotos.reset_index(inplace=True)
del largephotos['level_1']

# %% [markdown]
# For the 'breeds.primary' column I replace spaces with _ and / with nothing.

# %%
largephotos['breeds.primary'] = largephotos['breeds.primary'].str.replace(' ', '_')
largephotos['breeds.primary'] = largephotos['breeds.primary'].str.replace('/', '')

# %% [markdown]
# I check my value counts to see most popular breed in my dataset.

# %%
largephotos['breeds.primary'].value_counts()
# Out:
# Pit Bull Terrier       1524
# Labrador Retriever     1347
# Chihuahua               572
# Mixed Breed             495
# German Shepherd Dog     473
#                        ...
# Swedish Vallhund          1
# Pyrenean Shepherd         1
# Maltipoo                  1
# Schipperke                1
# Standard Poodle           1
# Name: breeds.primary, Length: 159, dtype: int64

# %%
largephotos = largephotos.groupby('breeds.primary').head()
largephotos.head()
# Out:
#          id                                             photos videos  \
# 0  45795879  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     []
# 1  45795880  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     []
# 2  45795882  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     []
# 3  45795884  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     []
# 4  45801263  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     []
#
#        breeds.primary breeds.secondary  breeds.mixed  breeds.unknown  \
# 0            Shepherd              NaN          True           False
# 1  Labrador Retriever       Cattle Dog          True           False
# 2            Shepherd              NaN          True           False
# 3          Cattle Dog              NaN         False           False
# 4  Labrador Retriever      Mixed Breed          True           False
#
#                          primary_photo_cropped.small  \
# 0  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 1  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 2  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 4  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                         primary_photo_cropped.medium  \
# 0  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 1  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 2  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 4  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                          primary_photo_cropped.large  \
# 0  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 1  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 2  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 4  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                           primary_photo_cropped.full  primary_photo_cropped  \
# 0  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...                    NaN
# 1  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...                    NaN
# 2  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...                    NaN
# 3  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...                    NaN
# 4  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...                    NaN
#
#    image_width
# 0          600
# 1          600
# 2          600
# 3          600
# 4          600

# %%
urls, breed, index = largephotos['primary_photo_cropped.large'].tolist(), largephotos['breeds.primary'].tolist(), largephotos.index.tolist()

# %% [markdown]
# I turn that into a list of lists

# %%
breed_list=[index, breed, urls]

# %%
breed_list_new = []
for i in range(0, len(breed_list[0])):
    breed_list_new.append([breed_list[0][i], breed_list[1][i], breed_list[2][i]])

# %% [markdown]
# Create breed directories for the images.

# %%
breed_dirs = list(largephotos['breeds.primary'].unique())

# %% [markdown]
# Create a directory, dog_breeds, that will contain all the breed directories.

# %%
for i in breed_dirs:
    os.makedirs('dog_breeds/' + str(i))

# %% [markdown]
# Next, I have a function to download the images.

# %%
def download_breed_images(breed_img):
    try:
        urllib.request.urlretrieve(breed_img[2], 
                                   os.path.join('dog_breeds/', 
                                                str(breed_img[1]), str(breed_img[1]) + str(breed_img[0]) + '.jpg'))
    except urllib.error.HTTPError as err:
        print(err.code)

# %%
pool = ThreadPool(processes=20)

# %%
pool.map(download_breed_images, breed_list_new)
pool.close()
pool.join()
