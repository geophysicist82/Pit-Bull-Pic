# %% [markdown]
# ## Data scraping and download (Round 2)

# %%
import time
import petpy
import os
import json
import pandas as pd
import urllib.request
import urllib.error
from multiprocessing import Pool
from multiprocessing.dummy import Pool as ThreadPool

# %%
key = os.getenv('PETFINDER_KEY')
pf = petpy.Petfinder('key', 'secret')

# %% [markdown]
# Since this is my second round of scraping dog images, I have decided to use Nashville as the location (since it's far enough from the center of Texas) and set the distance to 500 to cast a far net.
# I was able to get another 10k dogs

# %%
breeds = pf.animals(location=37011, animal_type='dog', distance=500, pages=100, results_per_page=100, return_df=True)

# %%
breeds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 50 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            10000 non-null  int64
#  1   organization_id               10000 non-null  object
#  2   url                           10000 non-null  object
#  3   type                          10000 non-null  object
#  4   species                       10000 non-null  object
#  5   age                           10000 non-null  object
#  6   gender                        10000 non-null  object
#  7   size                          10000 non-null  object
#  8   coat                          3239 non-null   object
#  9   tags                          10000 non-null  object
#  10  name                          10000 non-null  object
#  11  description                   7815 non-null   object
#  12  organization_animal_id        6742 non-null   object
#  13  photos                        10000 non-null  object
#  14  primary_photo_cropped         0 non-null      float64
#  15  videos                        10000 non-null  object
#  16  status                        10000 non-null  object
#  17  status_changed_at             10000 non-null  object
#  18  published_at                  10000 non-null  object
#  19  distance                      10000 non-null  float64
#  20  breeds.primary                10000 non-null  object
#  21  breeds.secondary              3719 non-null   object
#  22  breeds.mixed                  10000 non-null  bool
#  23  breeds.unknown                10000 non-null  bool
#  24  colors.primary                4527 non-null   object
#  25  colors.secondary              2251 non-null   object
#  26  colors.tertiary               158 non-null    object
#  27  attributes.spayed_neutered    10000 non-null  bool
#  28  attributes.house_trained      10000 non-null  bool
#  29  attributes.declawed           0 non-null      object
#  30  attributes.special_needs      10000 non-null  bool
#  31  attributes.shots_current      10000 non-null  bool
#  32  environment.children          2855 non-null   object
#  33  environment.dogs              3667 non-null   object
#  34  environment.cats              1843 non-null   object
#  35  contact.email                 9507 non-null   object
#  36  contact.phone                 8379 non-null   object
#  37  contact.address.address1      6819 non-null   object
#  38  contact.address.address2      778 non-null    object
#  39  contact.address.city          10000 non-null  object
#  40  contact.address.state         10000 non-null  object
#  41  contact.address.postcode      9987 non-null   object
#  42  contact.address.country       10000 non-null  object
#  43  animal_id                     10000 non-null  object
#  44  animal_type                   10000 non-null  object
#  45  organization_id               10000 non-null  object
#  46  primary_photo_cropped.small   9713 non-null   object
#  47  primary_photo_cropped.medium  9713 non-null   object
#  48  primary_photo_cropped.large   9713 non-null   object
#  49  primary_photo_cropped.full    9713 non-null   object
# dtypes: bool(6), float64(2), int64(1), object(41)
# memory usage: 3.4+ MB

# %%
breeds.head()
# Out:
#          id organization_id  \
# 0  49398423            OH82
# 1  49398414            OH82
# 2  49398415            OH82
# 3  49398421            OH82
# 4  49398412            OH82
#
#                                                  url type species    age  \
# 0  https://www.petfinder.com/dog/eden-49398423/oh...  Dog     Dog  Young
# 1  https://www.petfinder.com/dog/valerie-49398414...  Dog     Dog  Adult
# 2  https://www.petfinder.com/dog/halen-49398415/o...  Dog     Dog  Adult
# 3  https://www.petfinder.com/dog/nate-49398421/oh...  Dog     Dog  Young
# 4  https://www.petfinder.com/dog/ace-49398412/oh/...  Dog     Dog  Adult
#
#    gender    size  coat tags  ... contact.address.state  \
# 0  Female  Medium  None   []  ...                    OH
# 1  Female  Medium  None   []  ...                    OH
# 2    Male  Medium  None   []  ...                    OH
# 3    Male   Small  None   []  ...                    OH
# 4    Male   Large  None   []  ...                    OH
#
#   contact.address.postcode contact.address.country animal_id  animal_type  \
# 0                    45458                      US  49398423          dog
# 1                    45458                      US  49398414          dog
# 2                    45458                      US  49398415          dog
# 3                    45458                      US  49398421          dog
# 4                    45458                      US  49398412          dog
#
#   organization_id primary_photo_cropped.small primary_photo_cropped.medium  \
# 0            oh82                         NaN                          NaN
# 1            oh82                         NaN                          NaN
# 2            oh82                         NaN                          NaN
# 3            oh82                         NaN                          NaN
# 4            oh82                         NaN                          NaN
#
#   primary_photo_cropped.large  primary_photo_cropped.full
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
# [5 rows x 50 columns]

# %% [markdown]
# Here I drop many of the columns I don't need to clean up my dataframe.

# %%
# i am dropping columns i dont need
breeds.drop(columns=['attributes.spayed_neutered','attributes.house_trained','attributes.declawed',
                    'attributes.special_needs','attributes.shots_current','environment.children', 
                     'environment.dogs', 'environment.cats','contact.email', 'contact.phone', 
                     'contact.address.address1','contact.address.address2', 'contact.address.city',
                     'contact.address.state', 'contact.address.postcode',
                     'contact.address.country','organization_id','status', 'tags',
                     'status_changed_at', 'published_at', 'distance', 'animal_id',
                     'organization_animal_id'], inplace=True)

# %% [markdown]
# I am again going to export my dataframe to a CSV so I will not have to re-scrape any data.

# %%
#breeds.to_csv('./data/10k_mostlyraw_nashville_10-09-20.csv')

# %%
#breeds=pd.read_csv('./data/10k_mostlyraw_9-16-20.csv')

# %%
breeds.columns
# Out:
# Index(['id', 'url', 'type', 'species', 'age', 'gender', 'size', 'coat', 'name',
#        'description', 'photos', 'primary_photo_cropped', 'videos',
#        'breeds.primary', 'breeds.secondary', 'breeds.mixed', 'breeds.unknown',
#        'colors.primary', 'colors.secondary', 'colors.tertiary', 'animal_type',
#        'primary_photo_cropped.small', 'primary_photo_cropped.medium',
#        'primary_photo_cropped.large', 'primary_photo_cropped.full'],
#       dtype='object')

# %%
pf.animal_types('dog')
# Out:
# {'type': {'name': 'Dog',
#   'coats': ['Hairless', 'Short', 'Medium', 'Long', 'Wire', 'Curly'],
#   'colors': ['Apricot / Beige',
#    'Bicolor',
#    'Black',
#    'Brindle',
#    'Brown / Chocolate',
#    'Golden',
#    'Gray / Blue / Silver',
#    'Harlequin',
#    'Merle (Blue)',
#    'Merle (Red)',
#    'Red / Chestnut / Orange',
#    'Sable',
#    'Tricolor (Brown, Black, & White)',
#    'White / Cream',
#    'Yellow / Tan / Blond / Fawn'],
#   'genders': ['Male', 'Female'],
#   '_links': {'self': {'href': '/v2/types/dog'},
#    'breeds': {'href': '/v2/types/dog/breeds'}}}}

# %% [markdown]
# I am dropping all rows that have null values for all the photo columns.

# %%
breeds = breeds[breeds['primary_photo_cropped.small'].notna()]
breeds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9713 entries, 5 to 9999
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            9713 non-null   int64
#  1   url                           9713 non-null   object
#  2   type                          9713 non-null   object
#  3   species                       9713 non-null   object
#  4   age                           9713 non-null   object
#  5   gender                        9713 non-null   object
#  6   size                          9713 non-null   object
#  7   coat                          3208 non-null   object
#  8   name                          9713 non-null   object
#  9   description                   7703 non-null   object
#  10  photos                        9713 non-null   object
#  11  primary_photo_cropped         0 non-null      float64
#  12  videos                        9713 non-null   object
#  13  breeds.primary                9713 non-null   object
#  14  breeds.secondary              3620 non-null   object
#  15  breeds.mixed                  9713 non-null   bool
#  16  breeds.unknown                9713 non-null   bool
#  17  colors.primary                4430 non-null   object
#  18  colors.secondary              2195 non-null   object
#  19  colors.tertiary               158 non-null    object
#  20  animal_type                   9713 non-null   object
#  21  primary_photo_cropped.small   9713 non-null   object
#  22  primary_photo_cropped.medium  9713 non-null   object
#  23  primary_photo_cropped.large   9713 non-null   object
#  24  primary_photo_cropped.full    9713 non-null   object
# dtypes: bool(2), float64(1), int64(1), object(21)
# memory usage: 1.8+ MB

# %% [markdown]
# I am saving another version of the dataframe to csv.

# %%
#breeds.to_csv('./data/10k_mostlyraw_nashville_10-09-20CLEANED.csv')

# %%
#breeds=pd.read_csv('./data/10k_mostlyraw_9-16-20CLEANED.csv')

# %% [markdown]
# Now I remove all columns except ones that contain id, breed and photo.

# %%
photos = breeds[breeds.columns[breeds.columns.str.contains('id|breed|photo')]]

# %%
photos
# Out:
#             id                                             photos  \
# 5     49398401  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 6     49398290  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 7     49393253  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 8     49398318  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 10    49398317  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# ...        ...                                                ...
# 9995  49088756  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 9996  49088535  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 9997  49088674  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 9998  49088617  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 9999  49088638  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
#
#       primary_photo_cropped videos                       breeds.primary  \
# 5                       NaN     []                          Mixed Breed
# 6                       NaN     []  Australian Cattle Dog / Blue Heeler
# 7                       NaN     []                              Terrier
# 8                       NaN     []                             Shepherd
# 10                      NaN     []                             Shepherd
# ...                     ...    ...                                  ...
# 9995                    NaN     []                     American Bulldog
# 9996                    NaN     []                   Miniature Pinscher
# 9997                    NaN     []                        Border Collie
# 9998                    NaN     []                     Golden Retriever
# 9999                    NaN     []                                Boxer
#
#          breeds.secondary  breeds.mixed  breeds.unknown  \
# 5                    None          True           False
# 6     German Shepherd Dog          True           False
# 7                    None          True           False
# 8                    None          True           False
# 10                   None          True           False
# ...                   ...           ...             ...
# 9995                 None          True           False
# 9996                 None         False           False
# 9997          Mixed Breed          True           False
# 9998                 None         False           False
# 9999                Hound          True           False
#
#                             primary_photo_cropped.small  \
# 5     https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 6     https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 7     https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 8     https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 10    https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# ...                                                 ...
# 9995  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 9996  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 9997  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 9998  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 9999  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                            primary_photo_cropped.medium  \
# 5     https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 6     https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 7     https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 8     https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 10    https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# ...                                                 ...
# 9995  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 9996  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 9997  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 9998  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 9999  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                             primary_photo_cropped.large  \
# 5     https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 6     https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 7     https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 8     https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 10    https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# ...                                                 ...
# 9995  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 9996  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 9997  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 9998  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 9999  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                              primary_photo_cropped.full
# 5     https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 6     https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 7     https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 8     https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 10    https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# ...                                                 ...
# 9995  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 9996  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 9997  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 9998  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 9999  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
# [9713 rows x 12 columns]

# %% [markdown]
# I am getting the size of the largest photos because those are the ones I will download.

# %%
# i am getting the size of the largest photo
photos['image_width'] = photos['primary_photo_cropped.large'].str.split('width=', 1).str[1].str.split('&', 0).str[0].astype(int)
# Out:
# /Users/jennyjames/opt/anaconda3/envs/dsir/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# I create a column called image_width to display the size of the large photos.

# %%
photos['image_width'].unique()
# Out:
# array([600])

# %% [markdown]
# I set the index to be the dog id column.

# %%
photos.set_index('id')
# Out:
#                                                      photos  \
# id
# 49398401  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 49398290  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 49393253  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 49398318  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 49398317  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# ...                                                     ...
# 49088756  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 49088535  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 49088674  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 49088617  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 49088638  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
#
#           primary_photo_cropped videos                       breeds.primary  \
# id
# 49398401                    NaN     []                          Mixed Breed
# 49398290                    NaN     []  Australian Cattle Dog / Blue Heeler
# 49393253                    NaN     []                              Terrier
# 49398318                    NaN     []                             Shepherd
# 49398317                    NaN     []                             Shepherd
# ...                         ...    ...                                  ...
# 49088756                    NaN     []                     American Bulldog
# 49088535                    NaN     []                   Miniature Pinscher
# 49088674                    NaN     []                        Border Collie
# 49088617                    NaN     []                     Golden Retriever
# 49088638                    NaN     []                                Boxer
#
#              breeds.secondary  breeds.mixed  breeds.unknown  \
# id
# 49398401                 None          True           False
# 49398290  German Shepherd Dog          True           False
# 49393253                 None          True           False
# 49398318                 None          True           False
# 49398317                 None          True           False
# ...                       ...           ...             ...
# 49088756                 None          True           False
# 49088535                 None         False           False
# 49088674          Mixed Breed          True           False
# 49088617                 None         False           False
# 49088638                Hound          True           False
#
#                                 primary_photo_cropped.small  \
# id
# 49398401  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49398290  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49393253  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49398318  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49398317  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# ...                                                     ...
# 49088756  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49088535  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49088674  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49088617  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49088638  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                                primary_photo_cropped.medium  \
# id
# 49398401  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49398290  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49393253  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49398318  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49398317  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# ...                                                     ...
# 49088756  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49088535  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49088674  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49088617  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49088638  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                                 primary_photo_cropped.large  \
# id
# 49398401  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49398290  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49393253  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49398318  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49398317  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# ...                                                     ...
# 49088756  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49088535  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49088674  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49088617  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49088638  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                                  primary_photo_cropped.full  image_width
# id
# 49398401  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...          600
# 49398290  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...          600
# 49393253  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...          600
# 49398318  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...          600
# 49398317  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...          600
# ...                                                     ...          ...
# 49088756  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...          600
# 49088535  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...          600
# 49088674  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...          600
# 49088617  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...          600
# 49088638  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...          600
#
# [9713 rows x 12 columns]

# %% [markdown]
# I need to drop the primary_photo_cropped column since it is empty.

# %%
photos.drop(columns=['primary_photo_cropped'], inplace=True)
photos.head()
# Out:
# /Users/jennyjames/opt/anaconda3/envs/dsir/lib/python3.7/site-packages/pandas/core/frame.py:4167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#           id                                             photos videos  \
# 5   49398401  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     []
# 6   49398290  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     []
# 7   49393253  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     []
# 8   49398318  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     []
# 10  49398317  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...     []
#
#                          breeds.primary     breeds.secondary  breeds.mixed  \
# 5                           Mixed Breed                 None          True
# 6   Australian Cattle Dog / Blue Heeler  German Shepherd Dog          True
# 7                               Terrier                 None          True
# 8                              Shepherd                 None          True
# 10                             Shepherd                 None          True
#
#     breeds.unknown                        primary_photo_cropped.small  \
# 5            False  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 6            False  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 7            False  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 8            False  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 10           False  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                          primary_photo_cropped.medium  \
# 5   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 6   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 7   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 8   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 10  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                           primary_photo_cropped.large  \
# 5   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 6   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 7   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 8   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 10  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                            primary_photo_cropped.full  image_width
# 5   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...          600
# 6   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...          600
# 7   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...          600
# 8   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...          600
# 10  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...          600

# %% [markdown]
# I have decided to keep the photos that have a width of 600

# %%
lrgphotos = photos.groupby('id').apply(lambda x: x[x['image_width'] == 600])

# %%
lrgphotos.head()
# Out:
#                      id                                             photos  \
# id
# 46140200 9091  46140200  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 48849178 6426  48849178  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 49010594 7835  49010594  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 49029975 8737  49029975  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 49052909 7399  49052909  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
#
#               videos    breeds.primary  breeds.secondary  breeds.mixed  \
# id
# 46140200 9091     []  Pit Bull Terrier              None          True
# 48849178 6426     []        Weimaraner              None         False
# 49010594 7835     []         Dachshund              None         False
# 49029975 8737     []  Pit Bull Terrier              None         False
# 49052909 7399     []      Mountain Cur  Pit Bull Terrier          True
#
#                breeds.unknown  \
# id
# 46140200 9091           False
# 48849178 6426           False
# 49010594 7835           False
# 49029975 8737           False
# 49052909 7399           False
#
#                                      primary_photo_cropped.small  \
# id
# 46140200 9091  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 48849178 6426  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49010594 7835  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49029975 8737  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49052909 7399  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                                     primary_photo_cropped.medium  \
# id
# 46140200 9091  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 48849178 6426  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49010594 7835  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49029975 8737  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49052909 7399  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                                      primary_photo_cropped.large  \
# id
# 46140200 9091  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 48849178 6426  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49010594 7835  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49029975 8737  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 49052909 7399  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                                       primary_photo_cropped.full  image_width
# id
# 46140200 9091  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...          600
# 48849178 6426  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...          600
# 49010594 7835  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...          600
# 49029975 8737  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...          600
# 49052909 7399  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...          600

# %% [markdown]
# Now my dataset has a few extra columns so I delete those and reset the index to be the dog id.

# %%
del lrgphotos['id']
lrgphotos.reset_index(inplace=True)
del lrgphotos['level_1']

# %% [markdown]
# For the 'breeds.primary' column I replace spaces with _ and / with nothing.

# %%
lrgphotos['breeds.primary'] = lrgphotos['breeds.primary'].str.replace(' ', '_')
lrgphotos['breeds.primary'] = lrgphotos['breeds.primary'].str.replace('/', '')

# %% [markdown]
# I check my value counts to see most popular breed in my dataset. Just like my last scrape, the Pit Bull Terrier has the highest count.

# %%
lrgphotos['breeds.primary'].value_counts()
# Out:
# Pit Bull Terrier                      1344
# Labrador Retriever                    1039
# Mixed Breed                            936
# Terrier                                509
# Hound                                  462
#                                       ...
# McNab                                    1
# Akbash                                   1
# Nova Scotia Duck Tolling Retriever       1
# Pyrenean Shepherd                        1
# Pembroke Welsh Corgi                     1
# Name: breeds.primary, Length: 172, dtype: int64

# %%
urls, breed, index = lrgphotos['primary_photo_cropped.large'].tolist(), lrgphotos['breeds.primary'].tolist(), lrgphotos.index.tolist()

# %%
breed_list=[index, breed, urls]

# %%
breed_list_new = []
for i in range(0, len(breed_list[0])):
    breed_list_new.append([breed_list[0][i], breed_list[1][i], breed_list[2][i]])

# %%
len(breed_list_new)
# Out:
# 9713

# %% [markdown]
# Create breed directories for the images.

# %%
breed_dirs = list(lrgphotos['breeds.primary'].unique())

# %% [markdown]
# Create a directory, dog_breeds, that will contain all the breed directories.

# %%
for i in breed_dirs:
    os.makedirs('dog_breeds/' + str(i))

# %% [markdown]
# A function to download the images.

# %%
def download_breed_images(breed_img):
    try:
        urllib.request.urlretrieve(breed_img[2], 
                                   os.path.join('dog_breeds/', 
                                                str(breed_img[1]), str(breed_img[1]) + str(breed_img[0]) + '.jpg'))
    except urllib.error.HTTPError as err:
        print(err.code)

# %%
pool = ThreadPool(processes=20)

# %%
pool.map(download_breed_images, breed_list_new)
pool.close()
pool.join()
# Out:
# 415
